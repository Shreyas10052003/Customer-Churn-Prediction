# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("heart.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.shape
# Out:
# (303, 14)

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data[data.duplicated()]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (302, 14)

# %%
numerical_cols=['age','trestbps','chol','thalach','oldpeak']
for col in numerical_cols:
    sns.histplot(data[col],kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#count plot
c_cols=['sex','cp','fbs','restecg','exang','slope','ca','thal','target']
for col in c_cols:
    sns.countplot(x=data[col])
    plt.title(f'Count of {col}')
    plt.show()

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=data['sex'],y=data['age'],hue=data['target'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 plt.figure(figsize=(5,4))
# ----> 2 sns.barplot(x=data['sex'],y=data['age'],hue=data['target'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
x=data.iloc[:,:-1]
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
scaled=m.fit_transform(x)
X=pd.DataFrame(scaled,columns=data.columns[:-1])
X
# Out:
#           age  sex        cp  trestbps      chol  fbs  restecg   thalach  \
# 0    0.708333  1.0  1.000000  0.481132  0.244292  1.0      0.0  0.603053
# 1    0.166667  1.0  0.666667  0.339623  0.283105  0.0      0.5  0.885496
# 2    0.250000  0.0  0.333333  0.339623  0.178082  0.0      0.0  0.770992
# 3    0.562500  1.0  0.333333  0.245283  0.251142  0.0      0.5  0.816794
# 4    0.583333  0.0  0.000000  0.245283  0.520548  0.0      0.5  0.702290
# ..        ...  ...       ...       ...       ...  ...      ...       ...
# 297  0.583333  0.0  0.000000  0.433962  0.262557  0.0      0.5  0.396947
# 298  0.333333  1.0  1.000000  0.150943  0.315068  0.0      0.5  0.465649
# 299  0.812500  1.0  0.000000  0.471698  0.152968  1.0      0.5  0.534351
# 300  0.583333  1.0  0.000000  0.339623  0.011416  0.0      0.5  0.335878
# 301  0.583333  0.0  0.333333  0.339623  0.251142  0.0      0.0  0.786260
#
#      exang   oldpeak  slope    ca      thal
# 0      0.0  0.370968    0.0  0.00  0.333333
# ...

# %%
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import *
model=DecisionTreeClassifier(random_state=42,criterion ="gini",splitter='best',max_depth=4)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8157894736842105

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
plt.xlabel('predicted labels')
plt.ylabel('Actual labels')
plt.show()

# %%
y_train.value_counts()
# Out:
# target
# 1    123
# 0    103
# Name: count, dtype: int64

# %%
#SMOTE - synthetic minortiy oversampling technique

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import *

# %%
smote= SMOTE(random_state=42)
X_train_resampled,y_train_resampled=smote.fit_resample(x_train,y_train)

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train_resampled,y_train_resampled)
y_pred=model.predict(x_test)
acc= accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7631578947368421

# %%
y_train_resampled.value_counts()
# Out:
# target
# 0    123
# 1    123
# Name: count, dtype: int64

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.76        35
#            1       0.83      0.71      0.76        41
#
#     accuracy                           0.76        76
#    macro avg       0.77      0.77      0.76        76
# weighted avg       0.77      0.76      0.76        76

# %%
#CROSS VALIDATION #hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
tree_clf = DecisionTreeClassifier()
params={
    "criterion":("gini","entropy"),
    "splitter":("best","random"),
    "max_depth":(list(range(1,15))),
    "min_samples_split":[2,3,4,5,6,7],
    "min_samples_leaf":list(range(1,10))
}
tree_cv = GridSearchCV(tree_clf,params,scoring="accuracy",cv=5)
tree_cv.fit(x_train,y_train)
print("Bestparameter",tree_cv.best_params_)
# Out:
# Bestparameter {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 4, 'splitter': 'random'}

# %%
best_params=tree_cv.best_params_
dt1=DecisionTreeClassifier(**best_params)
dt1.fit(x_train,y_train)
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7631578947368421

# %%
#ENSEMBLE METHODS 
# BAGGING, BOOSTING, STACKING
## Bagging = Multiple copies of the same type of model trained on different bootstrapped datasets → reduces overfitting.
##Stacking = Different types of models trained together, and their predictions are used as inputs for a meta-model → improves predictive accuracy

# %%
#RANDOM FOREST IN BAGGING
from sklearn.ensemble import RandomForestClassifier
rf_clf= RandomForestClassifier()
rf_clf.fit(x_train,y_train)
y_pred=rf_clf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8552631578947368

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85        35
#            1       0.89      0.83      0.86        41
#
#     accuracy                           0.86        76
#    macro avg       0.86      0.86      0.86        76
# weighted avg       0.86      0.86      0.86        76

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Random Forest Hyperparameter Tuning
n_estimators=[100,150,200,250,300]
max_features=['auto','log2']
max_depth =[10,20,30]
min_samples_split=[5,10]
min_samples_leaf=[2,4]

random_grid={'n_estimators':[100,150,200,250,300],'max_features':max_features,
             'max_depth':max_depth,'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf}
rf_clf1=RandomForestClassifier(random_state=42)

from sklearn.model_selection import GridSearchCV
rf_cv=GridSearchCV(estimator=rf_clf1,scoring='f1',param_grid=random_grid,cv=3,
                   verbose=2,n_jobs=-1)
rf_cv.fit(x_train,y_train)
rf_best_params=rf_cv.best_params_
print(f"Best Parameters:{rf_best_params})")
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Best Parameters:{'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100})

# %%
rf_clf2= RandomForestClassifier(**rf_best_params)
rf_clf2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_features='auto', min_samples_leaf=4,
#                        min_samples_split=10)

# %%
y_pred=rf_clf2.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8552631578947368

# %%
#BOOSTING
#adopt boosting, gradient boosting, XGboosting
#XGBOOSTING - Handles overfitting by its own by a method called regularisation(lasso nd ridge)

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier 
xgb=XGBClassifier(alpha=0.1,lambda_=0.1,max_depth=3,n_estimators=50,learning_rate=0.01)
xgb.fit(x_train,y_train)
y_hat=xgb.predict(x_test)

# %%
print(accuracy_score(y_hat,y_test))
# Out:
# 0.8289473684210527

# %%
#Hyper parameter tuning for xgboost
param_grid={'gamma':[0,0.1,0.2,0.4],
            'learning_rate':[0.01,0.03,0.06,0.1],
            'max_depth':[5,6,7,8,9],
            'n_estimators':[50,65,80],
            'alpha':[0,0.1,0.5,1],'lamda':[1,1.5,2,3]}
XGB=XGBClassifier(random_state=42)
rcv=GridSearchCV(estimator=XGB,scoring='accuracy',param_grid=param_grid,cv=3,
                   verbose=1,n_jobs=-1)
rcv.fit(x_train,y_train)
cv_best_params=rcv.best_params_
print(f"Best Parameters:{cv_best_params})")
# Out:
# Fitting 3 folds for each of 3840 candidates, totalling 11520 fits
# Best Parameters:{'alpha': 1, 'gamma': 0.4, 'lamda': 1, 'learning_rate': 0.03, 'max_depth': 5, 'n_estimators': 50})
