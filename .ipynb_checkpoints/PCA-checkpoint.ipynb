# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("glass.data")
data
# Out:
#      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   214 non-null    int64
#  1   RI      214 non-null    float64
#  2   Na      214 non-null    float64
#  3   Mg      214 non-null    float64
#  4   Al      214 non-null    float64
#  5   Si      214 non-null    float64
#  6   K       214 non-null    float64
#  7   Ca      214 non-null    float64
#  8   Ba      214 non-null    float64
#  9   Fe      214 non-null    float64
#  10  Class   214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]>

# %%
data.isnull().sum()
# Out:
# index    0
# RI       0
# Na       0
# Mg       0
# Al       0
# Si       0
# K        0
# Ca       0
# Ba       0
# Fe       0
# Class    0
# dtype: int64

# %%
#data.drop('index',axis=1,inplace=True) (Already Droped)

# %%
data.Class.unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
data.isnull().sum()
# Out:
# RI       0
# Na       0
# Mg       0
# Al       0
# Si       0
# K        0
# Ca       0
# Ba       0
# Fe       0
# Class    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data=data.drop_duplicates()

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
data=data.drop(columns='Class',axis=1)

# %%
data.head(3)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0

# %%
X=data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(X)
scaled_data
# Out:
# array([[ 0.87984017,  0.28955813,  1.25723832, ..., -0.14346582,
#         -0.35380764, -0.58830108],
#        [-0.24381562,  0.59640332,  0.63931074, ..., -0.79020061,
#         -0.35380764, -0.58830108],
#        [-0.71641202,  0.15454625,  0.6045957 , ..., -0.82534924,
#         -0.35380764, -0.58830108],
#        ...,
#        [ 0.76086485,  1.17327228, -1.86017161, ..., -0.36138732,
#          2.94550057, -0.58830108],
#        [-0.60735132,  1.19781989, -1.86017161, ..., -0.33326842,
#          2.80467644, -0.58830108],
#        [-0.40905912,  1.01371278, -1.86017161, ..., -0.23485225,
#          3.00585377, -0.58830108]])

# %%
data=pd.DataFrame(data=scaled_data,columns=X.columns)
data
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.879840  0.289558  1.257238 -0.706370 -1.133248 -0.673480 -0.143466
# 1   -0.243816  0.596403  0.639311 -0.180863  0.097037 -0.028962 -0.790201
# 2   -0.716412  0.154546  0.604596  0.182950  0.433746 -0.167073 -0.825349
# 3   -0.227291 -0.238216  0.701798 -0.322346 -0.058368  0.109149 -0.516041
# 4   -0.306608 -0.164573  0.653197 -0.423405  0.550299  0.078457 -0.621487
# ..        ...       ...       ...       ...       ...       ...       ...
# 208 -0.699888  0.903249 -1.860172  2.891336 -0.058368 -0.642789  0.158812
# 209 -0.494986  1.860605 -1.860172  1.092483  0.524398 -0.765554 -0.389506
# 210  0.760865  1.173272 -1.860172  1.153118  0.990612 -0.765554 -0.361387
# 211 -0.607351  1.197820 -1.860172  0.991424  1.236668 -0.765554 -0.333268
# 212 -0.409059  1.013713 -1.860172  1.274389  0.912909 -0.765554 -0.234852
#
#            Ba        Fe
# 0   -0.353808 -0.588301
# 1   -0.353808 -0.588301
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA()
principalComponents=pca.fit_transform(data)

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Variance (%)')
plt.title('Explained Variance')
plt.show()

# %%
pca=PCA(n_components=4)
new_data=pca.fit_transform(data)
#this is new data trained to algorithm
new_data
# Out:
# array([[ 1.14436230e+00, -5.23235234e-01, -3.18232856e-01,
#          1.76354525e+00],
#        [-5.73032508e-01, -7.62108880e-01, -5.26898359e-01,
#          7.78737097e-01],
#        [-9.33557001e-01, -9.33772981e-01, -5.41401369e-01,
#          2.24349317e-01],
#        [-1.33442622e-01, -9.62251706e-01, -1.01325336e-01,
#          4.22092536e-01],
#        [-3.40004538e-01, -1.09503000e+00, -4.80388799e-01,
#          8.55651341e-02],
#        [-2.60246849e-01, -1.32247332e+00,  8.30430850e-01,
#         -9.18635733e-01],
#        [-2.41497823e-01, -1.12056701e+00, -5.36467317e-01,
#          9.83150122e-02],
#        [-1.06422244e-01, -1.22713370e+00, -6.28291315e-01,
#         -9.44279368e-02],
#        [-2.58735772e-02, -3.18924117e-01, -6.15200341e-02,
#          1.37808785e+00],
#        [ 1.67592215e-02, -1.06622657e+00,  1.04491153e-01,
#         -3.61433961e-01],
#        [-3.50737704e-01, -1.38069618e+00,  6.44245788e-01,
#         -1.14731450e+00],
# ...

# %%
data=pd.DataFrame(data=new_data,columns=["PC1","PC2","PC3","PC4"])

# %%
data.head()
x=data
x
# Out:
#           PC1       PC2       PC3       PC4
# 0    1.144362 -0.523235 -0.318233  1.763545
# 1   -0.573033 -0.762109 -0.526898  0.778737
# 2   -0.933557 -0.933773 -0.541401  0.224349
# 3   -0.133443 -0.962252 -0.101325  0.422093
# 4   -0.340005 -1.095030 -0.480389  0.085565
# ..        ...       ...       ...       ...
# 208 -2.389960  3.056073  0.081664 -0.391639
# 209 -2.409179  3.090542 -1.110068  0.311494
# 210 -1.684782  3.270929 -0.943224 -0.148878
# 211 -2.371376  2.736765 -1.255252 -0.498340
# 212 -2.264866  3.011029 -0.908494 -0.397189
#
# [213 rows x 4 columns]

# %%
#create 2 models where in first model with all the features and second model with 3 pca features and check the performance of it
